# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5

word_counts = Counter(int_words)
total_count = len(int_words)

freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size + 1)

    start = (idx - R) if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # "200 is a good start"
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6688 0.4208 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6168 0.4085 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5165 0.4266 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6255 0.4272 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5065 0.4474 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5265 0.4501 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5314 0.4624 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5483 0.4474 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4973 0.4888 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4628 0.4389 sec/batch
# Nearest to time: dairy, dharma, valeria, multitasking, families, innovations, humanistic, gur,
# Nearest to more: amine, ancient, renaissance, challenging, broome, syncopated, elas, noone,
# Nearest to many: twickenham, principalities, yogurt, sutras, roller, thermochemistry, yourself, interdental,
# Nearest to some: fading, grueling, tailored, kermit, beiping, transmeta, triumph, metamorphic,
# Nearest to this: quranic, humanoid, bag, ld, geography, tabloids, prerelease, igad,
# Nearest to other: dicots, abducted, storing, casimir, dealers, atiyah, compiling, loi,
# Nearest to five: indefensible, didgeridoo, africa, monads, ftl, demeter, melito, removal,
# Nearest to the: superset, miltiades, curiae, evaluation, evanston, harsanyi, igf, wikipedia,
# Nearest to egypt: doris, mycologists, heterodox, afips, racing, to, ergosphere, greenfacts,
# Nearest to powers: anthology, rud, palmyra, polytheistic, sham, inertness, incited, scarface,
# Nearest to file: photographic, delmarva, cornerstone, j, kirkwood, cabinet, vojvodina, episcopate,
# Nearest to operating: talvela, fuego, ginette, seemed, dimboa, separates, enzyte, perak,
# Nearest to brother: umlaut, raisin, oldman, oust, scripting, lanky, isaurian, reefs,
# Nearest to professional: protestors, appointees, berlitz, athabasca, nto, suru, busman, memorization,
# Nearest to arts: factions, quench, lecturing, schwarzenberg, tinctures, kev, semper, volcano,
# Nearest to notes: barat, proselytes, enmity, robustness, photosynthetic, wavelets, sacramental, short,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5050 0.3858 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3996 0.3759 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3281 0.3767 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2719 0.3783 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1995 0.4557 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1743 0.4365 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1010 0.4851 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0556 0.4190 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9904 0.3824 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9683 0.3905 sec/batch
# Nearest to time: dairy, families, innovations, dharma, valeria, multitasking, voted, racing,
# Nearest to more: ancient, renaissance, suggested, came, south, challenging, sacrificed, medieval,
# Nearest to many: twickenham, opposed, yourself, when, roller, principalities, thermochemistry, efficient,
# Nearest to some: tailored, fading, variations, households, foreign, triumph, grueling, prone,
# Nearest to this: bag, geography, quranic, pc, ld, judge, biblical, exported,
# Nearest to other: member, storing, abducted, handle, dealers, sharing, sporadic, sexism,
# Nearest to five: indefensible, removal, africa, didgeridoo, content, suggesting, digestion, characters,
# Nearest to the: their, superset, she, usually, evaluation, miltiades, evanston, original,
# Nearest to egypt: racing, to, doris, harbors, heterodox, uses, mycologists, scripted,
# Nearest to powers: anthology, polytheistic, late, permanent, rud, look, approaching, opened,
# Nearest to file: photographic, j, cornerstone, cabinet, kirkwood, vojvodina, bombacaceae, comprehensive,
# Nearest to operating: seemed, talvela, synthesis, fuego, separates, zone, finished, ginette,
# Nearest to brother: umlaut, scripting, oldman, oust, reefs, lanky, penance, yeho,
# Nearest to professional: appointees, early, nto, suru, emma, band, protestors, paintings,
# Nearest to arts: factions, quench, lecturing, windsor, jim, years, kev, summit,
# Nearest to notes: proselytes, short, sacramental, barat, faithful, enmity, robustness, photosynthetic,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9437 0.4180 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8999 0.4122 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8717 0.4086 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8535 0.4445 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8271 0.4195 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8007 0.4544 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8192 0.4523 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7793 0.4263 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8030 0.4431 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7848 0.4573 sec/batch
# Nearest to time: innovations, dairy, dharma, valeria, multitasking, families, humanistic, restrictions,
# Nearest to more: renaissance, suggested, ancient, challenging, sacrificed, realised, saved, about,
# Nearest to many: twickenham, yourself, yogurt, principalities, roller, opposed, sutras, commonplace,
# Nearest to some: fading, tailored, triumph, grueling, variations, kermit, experiential, travels,
# Nearest to this: geography, ld, humanoid, quranic, bag, pc, judge, tabloids,
# Nearest to other: storing, abducted, sharing, recognizes, sexism, handle, dealers, labeled,
# Nearest to five: indefensible, digestion, removal, didgeridoo, africa, monads, consulting, archeologists,
# Nearest to the: wikipedia, their, she, curiae, superset, miltiades, inappropriate, styling,
# Nearest to egypt: heterodox, harbors, doris, to, mycologists, refuse, racing, gdynia,
# Nearest to powers: anthology, permanent, polytheistic, rud, holds, palmyra, look, enrico,
# Nearest to file: photographic, cornerstone, j, cabinet, altitude, kirkwood, comprehensive, bombacaceae,
# Nearest to operating: talvela, fuego, separates, seemed, zone, ginette, finished, encourages,
# Nearest to brother: umlaut, scripting, oust, reefs, kelly, oldman, arguable, penance,
# Nearest to professional: appointees, suru, succession, nto, protestors, early, catering, emma,
# Nearest to arts: factions, lecturing, quench, windsor, schwarzenberg, years, jim, volcano,
# Nearest to notes: proselytes, short, faithful, barat, xico, sacramental, incorporating, enmity,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7610 0.3858 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7641 0.3811 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7053 0.3752 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7361 0.3837 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7623 0.3809 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7125 0.3783 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7176 0.3846 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7057 0.3764 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7019 0.3835 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6649 0.3802 sec/batch
# Nearest to time: innovations, dairy, dharma, valeria, multitasking, gur, families, contestant,
# Nearest to more: suggested, renaissance, about, sacrificed, challenging, differing, elas, universally,
# Nearest to many: twickenham, yourself, principalities, yogurt, sutras, commonplace, roller, cheered,
# Nearest to some: fading, grueling, tailored, kermit, dynasties, experiential, variations, transmeta,
# Nearest to this: ld, humanoid, quranic, geography, prerelease, bag, pc, tabloids,
# Nearest to other: storing, abducted, sexism, dealers, dicots, drive, sharing, casimir,
# Nearest to five: nine, one, archeologists, two, pamela, indefensible, unaspirated, africa,
# Nearest to the: their, chasm, wikipedia, noticeably, flavius, styling, curiae, inappropriate,
# Nearest to egypt: doris, mycologists, heterodox, refuse, harbors, to, afips, gdynia,
# Nearest to powers: permanent, palmyra, anthology, polytheistic, rud, holds, opened, grove,
# Nearest to file: photographic, cornerstone, j, altitude, cabinet, kirkwood, reduces, comprehensive,
# Nearest to operating: talvela, fuego, ginette, separates, urgently, forwarded, capabilities, pragmatist,
# Nearest to brother: umlaut, oust, oldman, penance, kelly, scripting, slain, commercialized,
# Nearest to professional: protestors, appointees, nto, catering, suru, mayoral, early, donne,
# Nearest to arts: schwarzenberg, quench, factions, lecturing, jim, cadets, windsor, kev,
# Nearest to notes: short, proselytes, incorporating, barat, sacramental, enmity, faithful, photosynthetic,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6849 0.3782 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6660 0.3807 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6253 0.4350 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6201 0.4172 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6557 0.4267 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6284 0.4044 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5622 0.3372 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5565 0.4716 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5169 0.4687 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5127 0.4604 sec/batch
# Nearest to time: innovations, dharma, multitasking, valeria, dairy, contestant, gur, keener,
# Nearest to more: about, suggested, renaissance, propagated, broome, easy, sacrificed, quotations,
# Nearest to many: twickenham, yourself, commonplace, sutras, yogurt, moeller, cheered, roller,
# Nearest to some: fading, variations, grueling, tailored, kermit, transmeta, experiential, dynasties,
# Nearest to this: humanoid, quranic, ld, prerelease, bag, unlawful, geography, pc,
# Nearest to other: storing, sexism, abducted, dicots, unknowingly, handle, sharing, vigil,
# Nearest to five: nine, one, two, six, nd, pamela, d, unaspirated,
# Nearest to the: their, flavius, wikipedia, noticeably, dominate, usually, curiae, cleared,
# Nearest to egypt: doris, mycologists, refuse, beit, afips, lascaux, foodstuff, primrose,
# Nearest to powers: palmyra, anthology, rud, permanent, sham, polytheistic, flue, opened,
# Nearest to file: cornerstone, photographic, reduces, bombacaceae, altitude, j, comprehensive, straining,
# Nearest to operating: talvela, fuego, ginette, urgently, kernel, capabilities, forwarded, separates,
# Nearest to brother: umlaut, kelly, oust, raisin, isaurian, slain, penance, william,
# Nearest to professional: protestors, catering, appointees, suru, athabasca, nto, band, timid,
# Nearest to arts: quench, schwarzenberg, lecturing, embryology, cadets, factions, kev, windsor,
# Nearest to notes: proselytes, barat, incorporating, enmity, short, sacramental, faithful, photosynthetic,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4747 0.4061 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4978 0.4198 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4530 0.4125 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4866 0.4252 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5122 0.4626 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4794 0.4152 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4551 0.4091 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3761 0.4282 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4190 0.4170 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4286 0.3857 sec/batch
# Nearest to time: innovations, multitasking, dharma, contestant, gur, valeria, dairy, keener,
# Nearest to more: supplementation, renaissance, suggested, quotations, propagated, easy, adhesives, sedative,
# Nearest to many: twickenham, yourself, scheldt, yogurt, commonplace, cheered, refitted, sutras,
# Nearest to some: fading, variations, tailored, though, kermit, grueling, transmeta, experiential,
# Nearest to this: quranic, humanoid, ld, prerelease, bag, corollaries, considers, see,
# Nearest to other: storing, sharing, sexism, abducted, dicots, drive, handle, vigil,
# Nearest to five: two, nine, one, six, pamela, est, africa, unaspirated,
# Nearest to the: their, flavius, usually, noticeably, dominate, wikipedia, miltiades, styling,
# Nearest to egypt: beit, refuse, mycologists, doris, lascaux, foodstuff, triomphe, afips,
# Nearest to powers: palmyra, permanent, rud, enrico, holds, flue, sham, arnaud,
# Nearest to file: cornerstone, photographic, reduces, j, straining, bombacaceae, unix, elkhart,
# Nearest to operating: talvela, capabilities, kernel, ginette, urgently, fuego, forwarded, separates,
# Nearest to brother: umlaut, isaurian, raisin, kelly, penance, oust, slain, william,
# Nearest to professional: protestors, catering, athabasca, appointees, nto, suru, band, timid,
# Nearest to arts: quench, schwarzenberg, lecturing, embryology, cadets, jim, windsor, kev,
# Nearest to notes: incorporating, short, barat, enmity, proselytes, sacramental, bile, faithful,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4324 0.3992 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4205 0.4055 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4413 0.4714 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3829 0.4394 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4067 0.3983 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4205 0.4032 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3788 0.3838 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3980 0.4181 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4321 0.4326 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3387 0.3914 sec/batch
# Nearest to time: innovations, gur, dharma, contestant, multitasking, hitting, compiling, valeria,
# Nearest to more: supplementation, propagated, renaissance, suggested, easy, flocks, manually, sacrificed,
# Nearest to many: twickenham, yourself, scheldt, yogurt, mulattos, lamotrigine, rooted, commonplace,
# Nearest to some: fading, kermit, though, tailored, variations, transmeta, grueling, experiential,
# Nearest to this: quranic, ld, humanoid, corollaries, bag, pc, measurable, orb,
# Nearest to other: storing, vigil, sharing, drive, abducted, dicots, pcb, sexism,
# Nearest to five: two, one, six, nine, est, pamela, nd, four,
# Nearest to the: their, recycling, assurances, arsenio, usually, miltiades, dominate, cleared,
# Nearest to egypt: beit, refuse, mycologists, scriptura, lascaux, doris, afips, triomphe,
# Nearest to powers: palmyra, permanent, enrico, rud, holds, flue, hutch, sham,
# Nearest to file: cornerstone, reduces, photographic, unix, j, interfacing, elkhart, comprehensive,
# Nearest to operating: capabilities, talvela, kernel, ginette, forwarded, urgently, fuego, upload,
# Nearest to brother: umlaut, isaurian, kelly, penance, raisin, william, oust, eldest,
# Nearest to professional: protestors, catering, athabasca, nto, suru, appointees, oratorio, timid,
# Nearest to arts: quench, schwarzenberg, lecturing, cadets, embryology, jim, windsor, kev,
# Nearest to notes: incorporating, short, barat, enmity, proselytes, sacramental, photosynthetic, psychological,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3862 0.4024 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3930 0.4307 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3557 0.4110 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3547 0.4057 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4057 0.3954 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3661 0.3973 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3332 0.3810 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4011 0.3830 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3475 0.3846 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3526 0.5012 sec/batch
# Nearest to time: innovations, contestant, dharma, gur, multitasking, compiling, cervix, keener,
# Nearest to more: supplementation, renaissance, propagated, though, manually, flocks, easy, syncopated,
# Nearest to many: twickenham, scheldt, mulattos, henotheism, yogurt, yourself, common, lamotrigine,
# Nearest to some: fading, variations, kermit, tailored, transmeta, though, religions, fossilized,
# Nearest to this: quranic, humanoid, ld, corollaries, messagepad, iannis, orb, considers,
# Nearest to other: storing, can, dicots, sharing, drive, vigil, pcb, endorsement,
# Nearest to five: two, nine, six, one, est, four, pamela, zero,
# Nearest to the: their, by, dominate, sanatan, legislative, flavius, arsenio, miltiades,
# Nearest to egypt: beit, refuse, mycologists, shia, scriptura, lascaux, triomphe, foodstuff,
# Nearest to powers: palmyra, permanent, enrico, holds, antagonistic, insist, militarized, dowager,
# Nearest to file: unix, cornerstone, photographic, j, interfacing, comprehensive, reduces, bombacaceae,
# Nearest to operating: capabilities, talvela, kernel, pc, upload, forwarded, ginette, fuego,
# Nearest to brother: umlaut, isaurian, recapture, eldest, slain, raisin, oust, penance,
# Nearest to professional: protestors, catering, athabasca, nto, appointees, timid, oratorio, suru,
# Nearest to arts: schwarzenberg, quench, lecturing, cadets, embryology, windsor, colleges, jim,
# Nearest to notes: incorporating, short, barat, sacramental, bile, enmity, psychological, proselytes,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3358 0.5202 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2791 0.4127 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3714 0.4079 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3714 0.4602 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3902 0.4252 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3008 0.4312 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2972 0.4383 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3800 0.4693 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2012 0.4045 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3042 0.3932 sec/batch
# Nearest to time: innovations, contestant, gur, dharma, keener, compiling, athenaeus, multitasking,
# Nearest to more: supplementation, renaissance, propagated, though, easy, cuts, schlesinger, manually,
# Nearest to many: scheldt, mulattos, twickenham, yourself, sociopathic, lamotrigine, yogurt, for,
# Nearest to some: fading, kermit, transmeta, though, variations, tailored, experiential, grueling,
# Nearest to this: quranic, humanoid, ld, corollaries, considers, messagepad, measurable, iannis,
# Nearest to other: dicots, sharing, storing, vigil, drive, pcb, admin, can,
# Nearest to five: two, nine, six, one, zero, four, est, pamela,
# Nearest to the: their, dominate, taxpayer, sanatan, by, westwards, noticeably, exacerbating,
# Nearest to egypt: beit, shia, mycologists, refuse, lascaux, mohammed, triomphe, anatolia,
# Nearest to powers: palmyra, permanent, holds, incited, antagonistic, enrico, militarized, dowager,
# Nearest to file: unix, photographic, cornerstone, interfacing, j, comprehensive, reduces, elkhart,
# Nearest to operating: capabilities, kernel, talvela, ginette, forwarded, pc, upload, unix,
# Nearest to brother: umlaut, isaurian, recapture, eldest, raisin, slain, penance, oldman,
# Nearest to professional: catering, protestors, athabasca, nto, suru, oratorio, appointees, brunell,
# Nearest to arts: quench, lecturing, schwarzenberg, colleges, embryology, school, cadets, jim,
# Nearest to notes: incorporating, barat, short, psychological, sacramental, downplays, bile, davey,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3009 0.4225 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3001 0.3813 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3196 0.1779 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2372 0.3918 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2321 0.3847 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2272 0.3830 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2042 0.3790 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1935 0.3837 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2466 0.3750 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1750 0.5489 sec/batch
# Nearest to time: innovations, gur, contestant, dharma, compiling, hitting, multitasking, keener,
# Nearest to more: renaissance, supplementation, though, propagated, easy, manually, ropes, perceived,
# Nearest to many: mulattos, scheldt, common, twickenham, yogurt, lamotrigine, refitted, sociopathic,
# Nearest to some: fading, transmeta, kermit, variations, though, tailored, puzzling, experiential,
# Nearest to this: quranic, humanoid, corollaries, orb, ld, messagepad, considers, depriving,
# Nearest to other: sharing, dicots, storing, vigil, drive, admin, member, sexism,
# Nearest to five: two, six, one, nine, four, zero, est, nd,
# Nearest to the: their, westwards, taxpayer, excavated, dominate, by, surrounding, exacerbating,
# Nearest to egypt: beit, shia, mycologists, refuse, lascaux, precious, foodstuff, attentive,
# Nearest to powers: palmyra, holds, imposition, privileges, permanent, antagonistic, dowager, incited,
# Nearest to file: photographic, unix, comprehensive, interfacing, j, cornerstone, monitor, documents,
# Nearest to operating: capabilities, kernel, talvela, unix, ginette, pc, forwarded, upload,
# Nearest to brother: umlaut, isaurian, recapture, eldest, raisin, slain, oust, battle,
# Nearest to professional: catering, protestors, athabasca, nto, suru, timid, score, brunell,
# Nearest to arts: quench, colleges, school, schwarzenberg, lecturing, cadets, embryology, windsor,
# Nearest to notes: incorporating, barat, short, davey, downplays, sacramental, psychological, idiom,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2560 0.4841 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2414 0.4330 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2446 0.4372 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1237 0.4298 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1460 0.4056 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1719 0.3964 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1945 0.4518 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1698 0.4399 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2207 0.4056 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1746 0.4850 sec/batch
# Nearest to time: innovations, gur, contestant, dharma, compiling, hitting, multitasking, upanishads,
# Nearest to more: renaissance, supplementation, easy, though, ropes, propagated, these, cuts,
# Nearest to many: mulattos, twickenham, common, scheldt, refitted, for, lamotrigine, sociopathic,
# Nearest to some: transmeta, kermit, fading, tailored, experiential, though, variations, puzzling,
# Nearest to this: quranic, humanoid, corollaries, ld, pc, measurable, aara, sequent,
# Nearest to other: vigil, storing, dicots, sharing, pcb, member, can, admin,
# Nearest to five: two, six, one, nine, zero, four, est, migrant,
# Nearest to the: their, by, recycling, sanatan, gratification, taxpayer, noticeably, usually,
# Nearest to egypt: beit, shia, mycologists, precious, lascaux, ascended, refuse, foodstuff,
# Nearest to powers: palmyra, dowager, privileges, imposition, holds, permanent, incited, enrico,
# Nearest to file: photographic, unix, interfacing, comprehensive, documents, j, monitor, ejector,
# Nearest to operating: capabilities, kernel, talvela, ginette, forwarded, unix, fuego, upload,
# Nearest to brother: umlaut, isaurian, recapture, raisin, slain, eldest, penance, arguable,
# Nearest to professional: catering, protestors, athabasca, nto, timid, suru, appointees, score,
# Nearest to arts: colleges, quench, school, schwarzenberg, lecturing, embryology, cadets, windsor,
# Nearest to notes: incorporating, barat, short, davey, downplays, bile, idiom, hierarchically,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1939 0.4355 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2113 0.3815 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1832 0.3831 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1371 0.4005 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2066 0.4476 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1676 0.6976 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1857 0.7699 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1771 0.7198 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1284 0.7411 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1669 0.7415 sec/batch
# Nearest to time: innovations, contestant, gur, compiling, dharma, booting, upanishads, athenaeus,
# Nearest to more: renaissance, though, easy, supplementation, ropes, these, cuts, loosed,
# Nearest to many: mulattos, twickenham, scheldt, common, refitted, sociopathic, jiva, for,
# Nearest to some: fading, transmeta, kermit, though, tailored, variations, puzzling, experiential,
# Nearest to this: quranic, corollaries, humanoid, considers, messagepad, nectar, rounding, ld,
# Nearest to other: storing, vigil, dicots, member, sharing, pcb, irreversibly, unrelated,
# Nearest to five: two, six, one, nine, four, zero, three, est,
# Nearest to the: sanatan, by, assurances, their, exacerbating, of, taxpayer, rival,
# Nearest to egypt: beit, shia, mycologists, precious, lascaux, southernmost, herodotus, senegal,
# Nearest to powers: palmyra, holds, dowager, privileges, imposition, permanent, incited, flue,
# Nearest to file: interfacing, unix, comprehensive, photographic, documents, users, packages, j,
# Nearest to operating: capabilities, kernel, talvela, unix, forwarded, upload, ginette, pc,
# Nearest to brother: umlaut, isaurian, recapture, raisin, slain, eldest, defeats, arguable,
# Nearest to professional: catering, athabasca, protestors, nto, timid, appointees, suru, score,
# Nearest to arts: colleges, school, quench, schwarzenberg, lecturing, cadets, embryology, columbia,
# Nearest to notes: incorporating, barat, short, davey, hierarchically, idiom, src, downplays,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1965 0.7507 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1752 0.7572 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1837 0.5780 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1893 0.5048 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1472 0.4550 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1415 0.4165 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1852 0.4087 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1222 0.4241 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2013 0.4677 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2103 0.4649 sec/batch
# Nearest to time: gur, contestant, innovations, compiling, dharma, manasseh, booting, wards,
# Nearest to more: renaissance, though, syncopated, easy, supplementation, cynical, prolific, schlesinger,
# Nearest to many: mulattos, twickenham, scheldt, common, henotheism, rooted, refitted, sociopathic,
# Nearest to some: transmeta, kermit, fading, though, tailored, variations, puzzling, fossilized,
# Nearest to this: quranic, corollaries, humanoid, considers, ld, bhagavan, messagepad, judge,
# Nearest to other: member, dicots, vigil, sharing, irreversibly, storing, recognizes, sexism,
# Nearest to five: two, six, nine, one, four, zero, three, seven,
# Nearest to the: by, inaugurated, in, their, of, sanatan, palaeologus, taxpayer,
# Nearest to egypt: beit, lascaux, mycologists, precious, shia, safavid, caracalla, cappadocia,
# Nearest to powers: palmyra, dowager, holds, imposition, permanent, privileges, incited, proceeding,
# Nearest to file: documents, interfacing, unix, photographic, comprehensive, j, filenames, format,
# Nearest to operating: capabilities, talvela, kernel, forwarded, ginette, pc, fuego, unix,
# Nearest to brother: isaurian, umlaut, recapture, eldest, raisin, defeats, slain, battle,
# Nearest to professional: catering, protestors, athabasca, nto, brunell, appointees, timid, teacher,
# Nearest to arts: colleges, school, quench, cadets, schwarzenberg, embryology, lecturing, art,
# Nearest to notes: incorporating, short, barat, davey, idiom, hierarchically, manion, bloomfield,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2318 0.4653 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1580 0.4079 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1302 0.4170 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1479 0.4249 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0525 0.3830 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1296 0.4100 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1747 0.4795 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1664 0.3937 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1695 0.0739 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1063 0.3864 sec/batch
# Nearest to time: gur, innovations, contestant, compiling, dharma, manasseh, booting, cervix,
# Nearest to more: renaissance, though, these, syncopated, easy, supplementation, deletions, loosed,
# Nearest to many: mulattos, common, twickenham, scheldt, for, refitted, associated, rooted,
# Nearest to some: fading, kermit, transmeta, though, tailored, variations, puzzling, fossilized,
# Nearest to this: quranic, aara, messagepad, humanoid, orb, corollaries, ld, rounding,
# Nearest to other: dicots, sharing, member, storing, admin, vigil, fittings, irreversibly,
# Nearest to five: two, six, one, nine, zero, four, three, est,
# Nearest to the: by, of, sanatan, in, inaugurated, exacerbating, taxpayer, westwards,
# Nearest to egypt: beit, precious, mycologists, lascaux, caracalla, herodotus, shia, safavid,
# Nearest to powers: palmyra, dowager, holds, imposition, privileges, permanent, incited, proceeding,
# Nearest to file: photographic, documents, unix, comprehensive, interfacing, filenames, format, packages,
# Nearest to operating: capabilities, talvela, ginette, kernel, forwarded, unix, fuego, pc,
# Nearest to brother: isaurian, recapture, umlaut, defeats, raisin, eldest, slain, battle,
# Nearest to professional: catering, protestors, athabasca, teacher, appointees, timid, nto, score,
# Nearest to arts: quench, colleges, school, embryology, lecturing, schwarzenberg, cadets, art,
# Nearest to notes: incorporating, short, idiom, barat, hierarchically, davey, src, bloomfield,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0809 0.3998 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0481 0.4032 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0917 0.4267 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0677 0.4326 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0759 0.4310 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0214 0.4311 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0735 0.4305 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0700 0.4377 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0786 0.4326 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0259 0.4255 sec/batch
# Nearest to time: innovations, gur, contestant, compiling, ripple, booting, dharma, hitting,
# Nearest to more: though, renaissance, these, easy, cuts, ropes, supplementation, syncopated,
# Nearest to many: mulattos, common, rooted, associated, twickenham, scheldt, for, refitted,
# Nearest to some: though, fading, kermit, tailored, transmeta, variations, puzzling, experiential,
# Nearest to this: quranic, aara, supposing, corollaries, orb, messagepad, rounding, ld,
# Nearest to other: dicots, sharing, member, storing, admin, irreversibly, vigil, can,
# Nearest to five: two, six, one, nine, four, zero, three, total,
# Nearest to the: by, of, in, their, exacerbating, it, westwards, inaugurated,
# Nearest to egypt: beit, precious, mycologists, lascaux, caracalla, herodotus, qumran, ascended,
# Nearest to powers: palmyra, holds, dowager, imposition, privileges, permanent, proceeding, incited,
# Nearest to file: interfacing, documents, photographic, unix, comprehensive, filenames, format, monitor,
# Nearest to operating: capabilities, talvela, ginette, kernel, unix, forwarded, upload, fuego,
# Nearest to brother: isaurian, recapture, umlaut, eldest, defeats, raisin, slain, headlining,
# Nearest to professional: catering, protestors, athabasca, appointees, nto, teacher, timid, association,
# Nearest to arts: colleges, quench, school, embryology, lecturing, cadets, schwarzenberg, art,
# Nearest to notes: incorporating, short, idiom, barat, hierarchically, src, ledger, davey,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0029 0.4499 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0242 0.4358 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0144 0.4328 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0769 0.4335 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0816 0.4147 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0615 0.4658 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0420 0.4500 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1174 0.4544 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0473 0.3910 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0451 0.3894 sec/batch
# Nearest to time: gur, compiling, innovations, contestant, ripple, the, dharma, voted,
# Nearest to more: renaissance, though, these, syncopated, supplementation, deletions, loosed, cuts,
# Nearest to many: common, rooted, mulattos, associated, henotheism, twickenham, for, sociopathic,
# Nearest to some: though, fading, kermit, variations, tailored, transmeta, fossilized, experiential,
# Nearest to this: quranic, corollaries, aara, supposing, considers, measurable, ld, solve,
# Nearest to other: member, dicots, vigil, sharing, holds, irreversibly, pcb, storing,
# Nearest to five: two, six, one, nine, zero, four, three, seven,
# Nearest to the: of, by, in, sanatan, a, inaugurated, it, exacerbating,
# Nearest to egypt: beit, precious, lascaux, caracalla, mycologists, ovations, qumran, gdynia,
# Nearest to powers: palmyra, holds, dowager, permanent, proceeding, flue, imposition, xdsl,
# Nearest to file: documents, interfacing, photographic, comprehensive, unix, filenames, ejector, format,
# Nearest to operating: capabilities, talvela, ginette, unix, vms, kernel, ultrasparc, pc,
# Nearest to brother: isaurian, recapture, umlaut, eldest, raisin, defeats, slain, headlining,
# Nearest to professional: protestors, appointees, catering, athabasca, teacher, nto, professionals, association,
# Nearest to arts: colleges, quench, school, embryology, arboretum, schwarzenberg, art, cadets,
# Nearest to notes: incorporating, idiom, short, hierarchically, barat, src, ledger, manion,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0673 0.3948 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0702 0.3919 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0671 0.3909 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0386 0.3810 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0554 0.4153 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0489 0.4588 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0688 0.4107 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0525 0.4043 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0699 0.4106 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0748 0.4237 sec/batch
# Nearest to time: innovations, compiling, gur, contestant, ripple, the, manasseh, at,
# Nearest to more: though, renaissance, these, supplementation, syncopated, deletions, cuts, hallucination,
# Nearest to many: common, mulattos, rooted, henotheism, associated, twickenham, scheldt, refitted,
# Nearest to some: though, fading, variations, theorize, tailored, kermit, experiential, puzzling,
# Nearest to this: quranic, corollaries, aara, messagepad, supposing, considers, geography, rounding,
# Nearest to other: dicots, member, irreversibly, holds, vigil, kindergartens, sharing, sake,
# Nearest to five: two, six, one, nine, four, zero, three, seven,
# Nearest to the: of, by, sanatan, in, their, inaugurated, arians, promulgation,
# Nearest to egypt: beit, lascaux, precious, caracalla, qumran, cappadocia, ovations, triomphe,
# Nearest to powers: palmyra, dowager, holds, permanent, proceeding, incited, alberti, sideline,
# Nearest to file: comprehensive, documents, interfacing, unix, photographic, filenames, format, kirkwood,
# Nearest to operating: capabilities, talvela, unix, ginette, formatting, vms, fuego, ultrasparc,
# Nearest to brother: isaurian, recapture, eldest, umlaut, raisin, slain, defeats, oust,
# Nearest to professional: athabasca, catering, appointees, protestors, teacher, professionals, golf, nto,
# Nearest to arts: colleges, quench, school, embryology, art, arboretum, cadets, schwarzenberg,
# Nearest to notes: incorporating, idiom, ledger, short, src, barat, hierarchically, manion,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0640 0.4479 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0065 0.4415 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0429 0.4595 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0800 0.4906 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0904 0.5394 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1228 0.3959 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1513 0.3896 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0389 0.4254 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0286 0.4419 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0621 0.4380 sec/batch
# Nearest to time: contestant, innovations, compiling, gur, ripple, manasseh, dharma, booting,
# Nearest to more: renaissance, though, these, syncopated, deletions, cuts, supplementation, loosed,
# Nearest to many: mulattos, rooted, common, twickenham, bona, associated, henotheism, scheldt,
# Nearest to some: though, fading, variations, theorize, fossilized, tailored, kermit, puzzling,
# Nearest to this: quranic, corollaries, aara, messagepad, rounding, supposing, considers, ld,
# Nearest to other: dicots, irreversibly, holds, member, kindergartens, can, reaffirming, vigil,
# Nearest to five: two, one, six, nine, zero, four, three, seven,
# Nearest to the: of, by, sanatan, taxpayer, in, a, exacerbating, inaugurated,
# Nearest to egypt: beit, lascaux, caracalla, ovations, qumran, precious, cappadocia, presidencia,
# Nearest to powers: palmyra, permanent, holds, dowager, sideline, incited, alberti, proceeding,
# Nearest to file: documents, comprehensive, unix, photographic, interfacing, filenames, j, format,
# Nearest to operating: capabilities, talvela, unix, kernel, ginette, formatting, seemed, fuego,
# Nearest to brother: isaurian, eldest, recapture, umlaut, raisin, grandparents, darin, defeats,
# Nearest to professional: athabasca, appointees, catering, teacher, protestors, professionals, norwegian, nto,
# Nearest to arts: colleges, quench, embryology, art, school, cadets, schwarzenberg, arboretum,
# Nearest to notes: incorporating, idiom, short, ledger, manion, hierarchically, src, barat,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9837 0.5114 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0124 0.4925 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0629 0.4339 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0253 0.4483 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0612 0.4536 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0413 0.4304 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0072 0.4236 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9861 0.4122 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0222 0.4003 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9758 0.4259 sec/batch
# Nearest to time: innovations, gur, compiling, contestant, manasseh, at, ripple, smith,
# Nearest to more: renaissance, though, these, syncopated, prolific, perceived, eph, many,
# Nearest to many: mulattos, associated, rooted, common, refitted, lamotrigine, sociopathic, for,
# Nearest to some: fading, though, variations, theorize, tailored, puzzling, triumph, kermit,
# Nearest to this: quranic, corollaries, aara, pliocene, was, considers, supposing, messagepad,
# Nearest to other: dicots, member, irreversibly, holds, can, unrelated, kindergartens, reaffirming,
# Nearest to five: two, one, six, nine, four, zero, three, seven,
# Nearest to the: of, by, in, sanatan, a, exacerbating, legalization, it,
# Nearest to egypt: beit, lascaux, cappadocia, caracalla, ovations, qumran, precious, presidencia,
# Nearest to powers: palmyra, holds, permanent, dowager, proceeding, incited, sovereign, imperiled,
# Nearest to file: format, photographic, documents, interfacing, comprehensive, filenames, unix, files,
# Nearest to operating: capabilities, talvela, unix, vms, kernel, formatting, ginette, seemed,
# Nearest to brother: isaurian, recapture, eldest, defeats, grandparents, slain, umlaut, raisin,
# Nearest to professional: teacher, appointees, athabasca, catering, professionals, protestors, norwegian, khaganate,
# Nearest to arts: colleges, quench, embryology, art, cadets, schwarzenberg, lecturing, discipline,
# Nearest to notes: incorporating, idiom, manion, ledger, hierarchically, src, short, barat,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9769 0.4240 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9438 0.4823 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0329 0.4298 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0081 0.4163 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0348 0.4283 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0022 0.4484 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9212 0.3899 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9669 0.3841 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9293 0.3867 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9773 0.4081 sec/batch
# Nearest to time: innovations, ripple, gur, the, compiling, contestant, at, breakout,
# Nearest to more: these, though, renaissance, many, baghdad, few, syncopated, outpaced,
# Nearest to many: associated, mulattos, rooted, common, scheldt, twickenham, refitted, more,
# Nearest to some: though, fading, theorize, mmo, variations, kermit, tailored, transmeta,
# Nearest to this: quranic, aara, its, corollaries, starting, was, pc, exponentiation,
# Nearest to other: holds, member, dicots, candy, pcb, vigil, sharing, can,
# Nearest to five: two, one, six, nine, four, zero, three, seven,
# Nearest to the: of, by, in, a, it, sanatan, their, to,
# Nearest to egypt: beit, lascaux, cappadocia, qumran, precious, caracalla, triomphe, ovations,
# Nearest to powers: palmyra, holds, dowager, proceeding, permanent, incited, imperiled, sovereign,
# Nearest to file: documents, photographic, filenames, files, interfacing, comprehensive, unix, format,
# Nearest to operating: talvela, capabilities, unix, vms, kernel, ginette, fuego, seemed,
# Nearest to brother: isaurian, recapture, umlaut, grandparents, raisin, eldest, slain, halting,
# Nearest to professional: appointees, athabasca, catering, teacher, protestors, professionals, association, golf,
# Nearest to arts: colleges, arboretum, schwarzenberg, quench, cadets, school, art, discipline,
# Nearest to notes: incorporating, idiom, ledger, hierarchically, manion, src, barat, davey,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0142 0.3867 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9893 0.3820 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9661 0.3834 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0150 0.4190 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0429 0.4347 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9458 0.4364 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0284 0.4305 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9930 0.4293 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9980 0.4317 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0236 0.4365 sec/batch
# Nearest to time: gur, innovations, compiling, contestant, ripple, voted, breakout, the,
# Nearest to more: these, though, syncopated, renaissance, many, deletions, universally, systran,
# Nearest to many: associated, rooted, mulattos, common, more, scheldt, henotheism, twickenham,
# Nearest to some: though, fading, theorize, variations, kermit, mmo, transmeta, sleepy,
# Nearest to this: corollaries, quranic, aara, considers, its, solving, rounding, superseded,
# Nearest to other: holds, member, can, vigil, irreversibly, have, dicots, pcb,
# Nearest to five: two, one, six, four, nine, zero, three, seven,
# Nearest to the: of, by, a, in, sanatan, to, with, it,
# Nearest to egypt: beit, lascaux, qumran, precious, gypsum, cappadocia, presidencia, caracalla,
# Nearest to powers: palmyra, holds, permanent, dowager, alberti, proceeding, sovereign, imperiled,
# Nearest to file: photographic, filenames, documents, comprehensive, format, files, interfacing, kirkwood,
# Nearest to operating: talvela, capabilities, vms, unix, kernel, virtualization, ginette, ultrasparc,
# Nearest to brother: isaurian, eldest, recapture, raisin, grandparents, umlaut, darin, halting,
# Nearest to professional: appointees, teacher, athabasca, association, professionals, catering, protestors, unilever,
# Nearest to arts: arboretum, colleges, schwarzenberg, quench, semper, cadets, discipline, lecturing,
# Nearest to notes: incorporating, ledger, idiom, hierarchically, manion, barat, src, short,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9851 0.4410 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9743 0.4015 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9723 0.4239 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9938 0.3872 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0014 0.4268 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9999 0.4573 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9723 0.4147 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9761 0.3797 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9567 0.3828 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0042 0.3854 sec/batch
# Nearest to time: innovations, the, compiling, contestant, at, gur, manasseh, ripple,
# Nearest to more: though, syncopated, these, renaissance, many, systran, majority, smaller,
# Nearest to many: mulattos, rooted, common, associated, scheldt, more, twickenham, henotheism,
# Nearest to some: though, fading, mmo, theorize, variations, from, tailored, number,
# Nearest to this: aara, its, was, corollaries, geography, congratulations, quranic, disqualification,
# Nearest to other: member, irreversibly, holds, can, or, reaffirming, have, dicots,
# Nearest to five: two, one, six, nine, four, zero, three, seven,
# Nearest to the: of, by, in, a, over, with, sanatan, to,
# Nearest to egypt: beit, lascaux, qumran, cappadocia, ovations, page, presidencia, caracalla,
# Nearest to powers: palmyra, dowager, permanent, sovereign, proceeding, imperiled, sideline, holds,
# Nearest to file: photographic, filenames, documents, comprehensive, files, interfacing, filename, kirkwood,
# Nearest to operating: talvela, capabilities, vms, unix, ginette, ultrasparc, virtualization, separates,
# Nearest to brother: isaurian, eldest, grandparents, recapture, raisin, umlaut, nephews, slain,
# Nearest to professional: appointees, athabasca, professionals, teacher, protestors, catering, unilever, golf,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7633 0.4408 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8073 0.4188 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8024 0.4020 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8146 0.3912 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8622 0.4040 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8596 0.3953 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8512 0.4032 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8677 0.4138 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8989 0.3973 sec/batch
# Nearest to time: at, by, was, the, ripple, period, to, hiatus,
# Nearest to more: these, than, though, are, many, larger, few, syncopated,
# Nearest to many: for, in, are, these, more, with, and, other,
# Nearest to some: are, though, number, other, mmo, not, uniquely, among,
# Nearest to this: the, its, and, a, for, of, an, in,
# Nearest to other: are, and, is, or, in, the, of, can,
# Nearest to five: two, four, one, six, three, zero, nine, seven,
# Nearest to the: of, by, a, and, in, with, to, this,
# Nearest to egypt: copper, beit, egyptian, philemon, toughening, cappadocia, sinai, saxonis,
# Nearest to powers: spiny, realms, sovereign, sideline, ketterle, alberti, fineness, publicist,
# Nearest to file: filenames, documents, files, format, proclamations, kirkwood, photographic, baghd,
# Nearest to operating: talvela, unix, vms, maori, kernel, capabilities, impenetrable, fuego,
# Nearest to brother: grandparents, darin, nephews, fergus, scripting, halting, eldest, oldman,
# Nearest to professional: professionals, medalists, appointees, association, medicine, golf, unilever, chartered,
# Nearest to arts: martial, discipline, arboretum, art, cadets, commerce, chuan, theater,
# Nearest to notes: ledger, incorporating, tuning, hierarchically, unsatisfied, tremolo, idiom, cantar,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8411 0.4195 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8603 0.4202 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8741 0.4052 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8798 0.3982 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8524 0.3837 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8882 0.3837 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8646 0.3961 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8357 0.4000 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8709 0.4014 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8547 0.4025 sec/batch
# Nearest to time: at, period, years, ripple, to, was, triassic, hiatus,
# Nearest to more: these, than, are, larger, though, few, and, while,
# Nearest to many: in, for, are, these, other, with, and, the,
# Nearest to some: are, though, number, other, not, mmo, surrounding, inclusion,
# Nearest to this: the, its, and, a, for, aara, of, in,
# Nearest to other: are, or, and, can, many, is, in, to,
# Nearest to five: two, four, one, six, zero, three, nine, seven,
# Nearest to the: of, by, and, a, in, to, with, also,
# Nearest to egypt: copper, egyptian, beit, philemon, cappadocia, sinai, toughening, lascaux,
# Nearest to powers: realms, spiny, sovereign, ketterle, sideline, publicist, athelstan, bugatti,
# Nearest to file: documents, filenames, format, files, kirkwood, proclamations, photographic, filename,
# Nearest to operating: talvela, unix, maori, vms, impenetrable, separates, corporative, fuego,
# Nearest to brother: nephews, grandparents, darin, fergus, eldest, halting, scripting, counsellors,
# Nearest to professional: professionals, medalists, appointees, unilever, association, golf, chartered, medicine,
# Nearest to arts: martial, discipline, arboretum, cadets, chuan, commerce, art, theater,
# Nearest to notes: ledger, incorporating, hierarchically, unsatisfied, tuning, banknotes, cantar, idiom,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8544 0.4105 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8373 0.4047 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8439 0.3998 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8397 0.3967 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8997 0.4159 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8388 0.4053 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9917 0.4080 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8876 0.4024 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9076 0.4264 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8092 0.4315 sec/batch
# Nearest to time: at, years, seven, ripple, hiatus, period, was, zero,
# Nearest to more: than, these, and, larger, are, though, while, few,
# Nearest to many: in, and, other, for, are, these, with, the,
# Nearest to some: though, are, number, mmo, a, other, surrounding, not,
# Nearest to this: the, its, and, for, a, in, of, aara,
# Nearest to other: are, and, or, many, in, as, has, the,
# Nearest to five: two, four, one, six, zero, nine, three, seven,
# Nearest to the: of, by, and, in, a, to, with, also,
# Nearest to egypt: copper, egyptian, beit, sinai, philemon, cappadocia, toughening, saxonis,
# Nearest to powers: spiny, realms, sovereign, sideline, ketterle, fineness, peete, jana,
# Nearest to file: documents, filenames, format, kirkwood, files, proclamations, baghd, photographic,
# Nearest to operating: talvela, maori, vms, unix, kernel, fuego, impenetrable, corporative,
# Nearest to brother: nephews, darin, grandparents, fergus, eldest, scripting, halting, amesbury,
# Nearest to professional: professionals, medalists, unilever, appointees, association, golf, medicine, debbie,
# Nearest to arts: martial, arboretum, discipline, chuan, theater, cadets, commerce, art,
# Nearest to notes: ledger, incorporating, hierarchically, unsatisfied, banknotes, cantar, tuning, lovejoy,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8087 0.4307 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8747 0.4119 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7837 0.3996 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8773 0.3909 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8461 0.3937 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8615 0.3891 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8967 0.2238 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8095 0.3900 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8470 0.3914 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8267 0.3933 sec/batch
# Nearest to time: at, was, years, by, to, the, period, he,
# Nearest to more: than, these, are, larger, while, and, many, though,
# Nearest to many: are, and, in, these, for, other, as, with,
# Nearest to some: are, though, other, number, a, mmo, or, epigraphic,
# Nearest to this: the, its, and, a, in, an, for, was,
# Nearest to other: are, or, in, and, many, is, has, several,
# Nearest to five: two, one, six, four, three, nine, zero, seven,
# Nearest to the: of, by, in, a, to, and, with, also,
# Nearest to egypt: copper, egyptian, beit, sinai, cappadocia, philemon, toughening, lascaux,
# Nearest to powers: spiny, sovereign, realms, ketterle, fineness, peete, sideline, incited,
# Nearest to file: format, documents, filenames, files, kirkwood, proclamations, baghd, spotless,
# Nearest to operating: talvela, vms, unix, maori, fuego, impenetrable, kernel, corporative,
# Nearest to brother: nephews, grandparents, darin, fergus, eldest, halting, scripting, counsellors,
# Nearest to professional: professionals, medalists, unilever, appointees, medicine, golf, debbie, chartered,
# Nearest to arts: martial, discipline, art, cadets, arboretum, chuan, commerce, grappling,
# Nearest to notes: ledger, incorporating, hierarchically, unsatisfied, banknotes, tuning, lycaeus, carburetor,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8173 0.3852 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8366 0.3781 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8276 0.4409 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7998 0.3887 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8413 0.4037 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8054 0.4242 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8914 0.4042 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7847 0.4216 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8002 0.4192 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7595 0.3936 sec/batch
# Nearest to time: at, was, period, seven, years, quickly, ripple, the,
# Nearest to more: than, these, are, and, while, many, for, few,
# Nearest to many: in, and, are, these, other, as, the, known,
# Nearest to some: are, though, other, number, not, mmo, inclusion, a,
# Nearest to this: the, its, and, a, for, an, in, of,
# Nearest to other: are, and, in, many, or, several, as, has,
# Nearest to five: two, four, one, six, zero, three, nine, seven,
# Nearest to the: of, by, and, a, with, in, to, this,
# Nearest to egypt: copper, egyptian, beit, sinai, cappadocia, lascaux, toughening, philemon,
# Nearest to powers: realms, sovereign, spiny, peete, incited, fineness, aylwin, sideline,
# Nearest to file: documents, format, files, filenames, proclamations, kirkwood, spotless, baghd,
# Nearest to operating: talvela, vms, unix, maori, fuego, impenetrable, kernel, lease,
# Nearest to brother: darin, grandparents, fergus, nephews, scripting, eldest, halting, amesbury,
# Nearest to professional: professionals, medalists, unilever, chartered, appointees, association, amateur, golf,
# Nearest to arts: martial, arboretum, art, theater, discipline, commerce, chuan, cadets,
# Nearest to notes: ledger, incorporating, hierarchically, lycaeus, banknotes, unsatisfied, cantar, carburetor,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7581 0.4759 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8387 0.4301 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8166 0.4097 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8368 0.4447 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8083 0.4140 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9142 0.4089 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8387 0.4446 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8412 0.4373 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8226 0.4120 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8271 0.4371 sec/batch
# Nearest to time: at, to, by, period, hiatus, the, was, years,
# Nearest to more: than, are, these, and, many, though, while, larger,
# Nearest to many: are, and, other, with, for, these, known, in,
# Nearest to some: are, other, though, number, among, inclusion, mmo, in,
# Nearest to this: the, its, a, and, an, for, aara, of,
# Nearest to other: are, and, many, or, in, is, has, several,
# Nearest to five: two, four, one, six, three, zero, nine, seven,
# Nearest to the: of, by, a, and, with, to, in, also,
# Nearest to egypt: egyptian, copper, beit, philemon, sinai, toughening, lascaux, presidencia,
# Nearest to powers: realms, spiny, sovereign, fineness, athelstan, ketterle, peete, jana,
# Nearest to file: documents, format, files, filenames, kirkwood, proclamations, spotless, filename,
# Nearest to operating: talvela, vms, kernel, maori, unix, impenetrable, fuego, separates,
# Nearest to brother: grandparents, darin, nephews, eldest, fergus, scripting, daughter, sister,
# Nearest to professional: professionals, medalists, unilever, amateur, association, golf, debbie, medicine,
# Nearest to arts: martial, arboretum, theater, cadets, art, discipline, chuan, commerce,
# Nearest to notes: ledger, incorporating, lycaeus, banknotes, cantar, unsatisfied, hierarchically, carburetor,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8923 0.3986 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8562 0.4335 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8315 0.4293 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8210 0.4026 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8779 0.4075 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8611 0.4032 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8492 0.4240 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8502 0.4345 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8151 0.3978 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8159 0.4014 sec/batch
# Nearest to time: at, period, the, years, seven, by, was, hiatus,
# Nearest to more: than, are, and, these, while, though, larger, many,
# Nearest to many: are, in, and, other, with, the, for, these,
# Nearest to some: are, other, in, though, number, or, as, of,
# Nearest to this: the, its, and, in, a, for, of, was,
# Nearest to other: are, and, in, or, many, the, of, as,
# Nearest to five: two, four, one, six, three, zero, nine, seven,
# Nearest to the: of, by, and, a, in, to, with, also,
# Nearest to egypt: egyptian, copper, beit, philemon, toughening, sinai, lascaux, presidencia,
# Nearest to powers: fineness, realms, sovereign, spiny, athelstan, aylwin, jana, ketterle,
# Nearest to file: documents, format, files, filenames, kirkwood, filename, proclamations, spotless,
# Nearest to operating: talvela, vms, unix, maori, kernel, fuego, corporative, separates,
# Nearest to brother: grandparents, fergus, nephews, darin, scripting, amesbury, sister, eldest,
# Nearest to professional: professionals, medalists, unilever, golf, appointees, naive, generalizing, amateur,
# Nearest to arts: martial, arboretum, theater, art, cadets, discipline, chuan, commerce,
# Nearest to notes: ledger, incorporating, banknotes, hierarchically, lycaeus, adjusts, rapid, carburetor,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8715 0.4064 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8192 0.4290 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9351 0.4072 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9032 0.3931 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8691 0.3813 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8311 0.3919 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7578 0.4055 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8614 0.3926 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7471 0.3911 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8691 0.3771 sec/batch
# Nearest to time: at, period, the, years, hiatus, he, ripple, to,
# Nearest to more: than, these, are, and, many, in, while, larger,
# Nearest to many: and, in, other, are, for, as, more, with,
# Nearest to some: are, though, number, other, a, as, in, inclusion,
# Nearest to this: the, and, its, a, for, of, in, an,
# Nearest to other: are, and, in, or, many, as, several, has,
# Nearest to five: two, four, one, zero, six, three, nine, seven,
# Nearest to the: of, by, a, and, in, with, also, to,
# Nearest to egypt: copper, egyptian, beit, philemon, toughening, sinai, lascaux, cappadocia,
# Nearest to powers: spiny, realms, fineness, sovereign, peete, jana, ketterle, aylwin,
# Nearest to file: format, files, filenames, documents, kirkwood, spotless, filename, proclamations,
# Nearest to operating: talvela, vms, unix, kernel, maori, pc, fuego, separates,
# Nearest to brother: grandparents, fergus, darin, scripting, nephews, amesbury, eldest, halting,
# Nearest to professional: medalists, professionals, unilever, debbie, amateur, naive, appointees, medicine,
# Nearest to arts: martial, art, discipline, cadets, chuan, grappling, budo, arboretum,
# Nearest to notes: ledger, incorporating, banknotes, lycaeus, cantar, carburetor, adjusts, hierarchically,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8469 0.4371 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8237 0.3817 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
